# %% [markdown]
# # <strong>Games Sales EDA </strong>

# %% [markdown]
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# Fields include
#
#    Rank - Ranking of overall sales
#
#    Name - The games name
#
#    Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
#    Year - Year of the game's release
#
#    Genre - Genre of the game
#
#    Publisher - Publisher of the game
#
#    NA_Sales - Sales in North America (in millions)
#
#    EU_Sales - Sales in Europe (in millions)
#
#    JP_Sales - Sales in Japan (in millions)
#
#    Other_Sales - Sales in the rest of the world (in millions)
#
#    Global_Sales - Total worldwide sales.
#
#    Source: Kaggle.com

# %% [markdown]
# ## <strong> 1) Load Data </strong>

# %%
# Import all necessary libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the table to a dataframe.
df = pd.read_csv('vgsales.csv')

# %% [markdown]
# ## <strong> 2) Explore Data </strong>

# %%
# Display first 8 columns of the Dataframe.
df.head(8)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7     New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                  Wii Play      Wii  2006.0          Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
# Check 'Platform' contents.
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
# Check 'Genre' contents.
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# ## <strong> 3) Data Wrangling</strong>

# %%
# Checking for null values.
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Display null values for more investigation.
df[df.isna().any(axis=1)]
# Out:
#         Rank                             Name Platform    Year         Genre  \
# 179      180                  Madden NFL 2004      PS2     NaN        Sports
# 377      378                 FIFA Soccer 2004      PS2     NaN        Sports
# 431      432       LEGO Batman: The Videogame      Wii     NaN        Action
# 470      471       wwe Smackdown vs. Raw 2006      PS2     NaN      Fighting
# 607      608                   Space Invaders     2600     NaN       Shooter
# ...      ...                              ...      ...     ...           ...
# 16427  16430                     Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                       The Smurfs      3DS     NaN        Action
# 16494  16497  Legends of Oz: Dorothy's Return      3DS  2014.0        Puzzle
# 16543  16546           Driving Simulator 2011       PC  2011.0        Racing
# 16553  16556                   Bound By Flame     X360  2014.0  Role-Playing
#
# ...

# %% [markdown]
# It's hard to deal with year and publisher null values as is shown,
#
# So the perfect sloution is to remove all null values.

# %%
# Remove all null values
df.dropna(inplace= True)

# %%
# Checking for null values.
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
# Check if the dataframe has duplicate values.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ___________________________________

# %% [markdown]
# Some Tests

# %%
#df[(df['Name'].str.contains("Assassin")) & (df['Publisher']=='Ubisoft')]

# %%
#df[(df['Name'].str.contains("Mario")) & (df['Publisher']=='Nintendo')]

# %%
#df2=df.groupby(['NA_Sales'],['EU_Sales'],['JP_Sales'],['Other_Sales']).sum()

# %% [markdown]
# _________________________

# %% [markdown]
# ## <strong> 4) Answering the Questions</strong>

# %% [markdown]
# ### <Strong> Q1- What is the Sales Growth Rate Over the Years? </Strong>

# %%
# Show the sales over the years
df2=df.groupby(['Year'])['Global_Sales'].sum().reset_index()

# %%
# Display first 4 rows
df2.head(4)
# Out:
#      Year  Global_Sales
# 0  1980.0         11.38
# 1  1981.0         35.77
# 2  1982.0         28.86
# 3  1983.0         16.79

# %%
# Check 'Year' content
df2['Year'].unique()
# Out:
# array([1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016., 2017., 2020.])

# %% [markdown]
# As shown above there is two years missing (2018, 2019).

# %%
# Adding year 2018.
r1={'Year':2018,'Global_Sales':0}
df2 = df2.append(r1, ignore_index=True)

# %%
# Adding year 2019.
r2={'Year':2019,'Global_Sales':0}
df2 = df2.append(r2, ignore_index=True)

# %%
# Check of the null values.
df2.isnull().sum()
# Out:
# Year            0
# Global_Sales    0
# dtype: int64

# %%
# Check 'Year' content.
df2['Year'].unique()
# Out:
# array([1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016., 2017., 2020., 2018., 2019.])

# %%
# Sort values by year.
df2=df2.sort_values(by=['Year'])

# %% [markdown]
# Next step is filling the missing sales value, based on the last 3 years average sales.

# %%
# Calculate 3 years average sales.
df2['MA']=df2['Global_Sales'].rolling(3,center=True).mean()

# %%
# Add average sales to the 'Year' missing value.
df2['Global_Sales'] = np.where(df2['Global_Sales']==0,df2['MA'],df2['Global_Sales'])

# %%
# Remove 'MA'.
del df2['MA']

# %%
# Display last 4 rows 
df2.tail(4)
# Out:
#       Year  Global_Sales
# 37  2017.0      0.050000
# 39  2018.0      0.016667
# 40  2019.0      0.096667
# 38  2020.0      0.290000

# %% [markdown]
# After filling the missing values we can calculate sales growth rate.

# %%
# Calculate grouth rate over the years.
df2['Sales_Growth'] = df2['Global_Sales'].pct_change()*100

# %%
df2
# Out:
#       Year  Global_Sales  Sales_Growth
# 0   1980.0     11.380000           NaN
# 1   1981.0     35.770000    214.323374
# 2   1982.0     28.860000    -19.317864
# 3   1983.0     16.790000    -41.822592
# 4   1984.0     50.360000    199.940441
# 5   1985.0     53.940000      7.108817
# 6   1986.0     37.070000    -31.275491
# 7   1987.0     21.740000    -41.354195
# 8   1988.0     47.220000    117.203312
# 9   1989.0     73.450000     55.548496
# 10  1990.0     49.390000    -32.756978
# 11  1991.0     32.230000    -34.743875
# 12  1992.0     76.160000    136.301582
# 13  1993.0     45.980000    -39.627101
# 14  1994.0     79.170000     72.183558
# 15  1995.0     88.110000     11.292156
# 16  1996.0    199.150000    126.024288
# 17  1997.0    200.980000      0.918905
# 18  1998.0    256.470000     27.609712
# 19  1999.0    251.270000     -2.027528
# 20  2000.0    201.560000    -19.783500
# 21  2001.0    331.470000     64.452272
# 22  2002.0    395.520000     19.323016
# ...

# %%
# Convert 'Year' to Int value type.
df2['Year']=df2['Year'].astype(int)

# %%
# Plot sales chart.
df2.plot(x='Year',y='Global_Sales',color='mediumseagreen',kind='bar',figsize=(15,14))

plt.show()

# %% [markdown]
# It's appears that 2008 had more sales.

# %%
# Plot growth rate chart
df2.plot(x='Year',y='Sales_Growth',color='mediumseagreen',kind='line',figsize=(14,8))

plt.show()

# %% [markdown]
# As shown above sales growth jumped to the highest value betwen 2015-2020.

# %% [markdown]
# ### <Strong> Q2- Which Console Had more Video Games Sales? </Strong>

# %%
df3=df.groupby(['Platform'])['Global_Sales'].sum().reset_index()

# %%
df3
# Out:
#    Platform  Global_Sales
# 0      2600         86.57
# 1       3DO          0.10
# 2       3DS        246.27
# 3        DC         15.97
# 4        DS        818.91
# 5        GB        254.42
# 6       GBA        305.62
# 7        GC        197.14
# 8       GEN         28.36
# 9        GG          0.04
# 10      N64        218.21
# 11      NES        251.07
# 12       NG          1.44
# 13       PC        254.70
# 14     PCFX          0.03
# 15       PS        727.39
# 16      PS2       1233.46
# 17      PS3        949.35
# 18      PS4        278.10
# 19      PSP        291.71
# 20      PSV         61.60
# 21      SAT         33.59
# 22      SCD          1.87
# 23     SNES        200.05
# 24     TG16          0.16
# 25       WS          1.42
# 26      Wii        909.81
# 27     WiiU         81.86
# 28     X360        969.60
# 29       XB        252.09
# 30     XOne        141.06

# %%
# Ploting
df3.plot(x='Platform',y='Global_Sales',color='mediumseagreen',kind='bar',figsize=(14,8))

plt.show()

# %% [markdown]
# PS2 is the king of all consoles, it's might because the long period before launching PS3.

# %% [markdown]
# ### <Strong> Q3- Which Category Had Most Games?  </Strong>

# %%
# Checking the sales by genre.
df.groupby(['Genre'])['Global_Sales'].sum().reset_index()
# Out:
#            Genre  Global_Sales
# 0         Action       1722.84
# 1      Adventure        234.59
# 2       Fighting        444.05
# 3           Misc        789.87
# 4       Platform        829.13
# 5         Puzzle        242.21
# 6         Racing        726.76
# 7   Role-Playing        923.83
# 8        Shooter       1026.20
# 9     Simulation        389.98
# 10        Sports       1309.24
# 11      Strategy        173.27

# %%
df4=df.groupby(['Genre'])['Name'].nunique().reset_index()

# %%
df4
# Out:
#            Genre  Name
# 0         Action  1898
# 1      Adventure  1038
# 2       Fighting   605
# 3           Misc  1291
# 4       Platform   579
# 5         Puzzle   491
# 6         Racing   760
# 7   Role-Playing  1206
# 8        Shooter   806
# 9     Simulation   711
# 10        Sports  1366
# 11      Strategy   578

# %%
# Sort before ploting.
df4=df4.sort_values(by=['Name'],ascending=False)

# %%
df4.plot(x='Genre',y='Name',color='mediumseagreen',kind='bar',figsize=(14,8))

plt.show()

# %% [markdown]
# Games Devlopment companies are focusing mostly on action games, and it has more sales than other category.

# %%
def excel(df,N):
    """
    This Function Helps to Export to Excel files.
    df: Data Frame to be exported.
    N: Name of the exported file.
    """
    df.to_excel(N+'.xlsx')

# %%
# Export all data frames to Excel files.
excel(df2,'Sales Growth')
excel(df3,'Best Selling Console')
excel(df4,'Number of Games by Category')

# %% [markdown]
# # <Strong>CRISP-DM</Strong>
# I used CRISP-DM Method on this Project:
#
# <Strong>Business Understanding:</Strong>
#
# My main objective is answering following qouestions:
#
# Q1- What are the Sales Growth Rate Over the Years?
#
# Q2- Which Console Had more Video Games Sales?
#
# Q3- Which Category Had Most Games?
#
# <Strong>Data Understanding:</Strong>
#
# As explained before:
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# Fields include
#
#    Rank - Ranking of overall sales
#
#    Name - The games name
#
#    Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
#    Year - Year of the game's release
#
#    Genre - Genre of the game
#
#    Publisher - Publisher of the game
#
#    NA_Sales - Sales in North America (in millions)
#
#    EU_Sales - Sales in Europe (in millions)
#
#    JP_Sales - Sales in Japan (in millions)
#
#    Other_Sales - Sales in the rest of the world (in millions)
#
#    Global_Sales - Total worldwide sales.
#
#    Source: Kaggle.com
#
#
# <Strong>Prepare Data:</Strong>
#
# its on Load & Explore Data as shown above point number 1 and 2.
#
# <Strong>Data Modeling:</Strong>
#
# For the modling its avaliable to find answeres on each qouestion.
#
# <Strong>Results:</Strong>
#
# You can find results on my blog: https://medium.com/@kudabaksh44/unveil-the-hidden-on-games-sales-history-7c880449d25d .
#
# Github Link: https://github.com/Abdul-Rahmman/Project1_DSND  .

# %% [markdown]
# # <strong>END  </strong>
